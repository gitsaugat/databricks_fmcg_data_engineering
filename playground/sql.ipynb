# %%
# %sql
select * from fmcg.gold.dim_gross_price LIMIT 10;

# %%
# %sql 
select sum(gross_price),product_code from fmcg.silver.gross_price group by product_code;

# %%
# %sql 
select sum(gross_price),product_code from fmcg.silver.gross_price group by product_code;

# %%
# %sql
SELECT *
FROM (
    SELECT *,
           ROW_NUMBER() OVER (
               PARTITION BY product_code
               ORDER BY month DESC
           ) AS rn
    FROM fmcg.silver.gross_price
) t
WHERE rn = 1;

# %%
# %sql
select * from fmcg.gold.dim_gross_price

# %%
# %sql
select * from fmcg.gold.fact_orders limit 50;

# %%
# %sql
select * from fmcg.gold.fact_orders where product_code = "b6b5f542b7bb3474f3e68bd1d13a7846b3bdba5e99a79e26ddd4e589c15944ac";
